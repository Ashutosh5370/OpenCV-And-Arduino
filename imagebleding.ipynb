# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("D:/puppy.jpeg")

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img , cv2.COLOR_RGB2HLS)
plt.imshow(img)

# %%
img2 =  cv2.imread("D:/a.jpg")
img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)

# %%
img1= cv2.imread("D:/puppy.jpeg")
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img2.shape
# Out:
# (450, 761, 3)

# %%
img1 =cv2.resize(img1,(1200,1200))
img2 =cv2.resize(img2,(1200,1200))

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(img1 , 0.3 , img2 , 0.9 , 0 )
plt.imshow(blended)

# %%
img1= cv2.imread("D:/puppy.jpeg")
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)
img2 =  cv2.imread("D:/a.jpg")
img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
cv2.resize(img1 , (400 ,400))
plt.imshow(img1)

# %%
img2[0 , 450 : 0 ,400] = img1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-48f157e94e6e> in <module>()
# ----> 1 img2[0 , 400 : 0 ,400] = img1
#
# IndexError: index 400 is out of bounds for axis 2 with size 3

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('D:/cat.jpeg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)

# %%
plt.imshow(img)

# %%
 img = cv2.imread('D:/cat.jpeg')

# %%
img.shape
# Out:
# (331, 500, 3)

# %%
img2 = cv2.imread('D:/copy.jpg')

# %%
img1 = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1  =cv2.resize(img1,(600,600))
img2 = cv2.resize(img2 ,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
blended = cv2.addWeighted(img1 , 1 , img2 , 0.1 ,0 )

# %%
plt.imshow(blended)

# %%
img1 = cv2.imread('D:/cat.jpeg')
img2 = cv2.imread('D:/copy.jpg')
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2 ,(200,200))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2

# %%
large_img[0:200 , 0:200 ] = small_img

# %%
plt.imshow(large_img)

# %%
img1 = cv2.imread('D:/cat.jpeg')
img2 = cv2.imread('D:/copy.jpg')
img1 = cv2.cvtColor(img1 , cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2 ,(200,200))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (331, 500, 3)

# %%
x_offset = 500 - 200
y_offset = 331-200

# %%
img2.shape
# Out:
# (200, 200, 3)

# %%
rows ,cols , channels = img2.shape

# %%
cols
# Out:
# 200

# %%
roi = img1[y_offset: 331 , x_offset:500]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2 , cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray , cmap='gray')

# %%
mask_inv = cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv , cmap='gray')

# %%
mask_inv.shape
# Out:
# (200, 200)

# %%
import numpy as np

# %%
white_backgraoud = np.full(img2.shape , 255)

# %%
white_backgraoud.shape
# Out:
# (200, 200, 3)

# %%
bk = cv2.bitwise_or(white_backgraoud  ,white_backgraoud , mask = mask_inv)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2 ,img2 , mask= mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi = cv2.bitwise_or(roi ,fg)

# %%
plt.imshow(final_roi)
